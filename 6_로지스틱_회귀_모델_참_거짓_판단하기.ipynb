# %% [markdown]
# <a href="https://colab.research.google.com/github/ysy202202256/mypython/blob/main/6_%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1_%ED%9A%8C%EA%B7%80_%EB%AA%A8%EB%8D%B8_%EC%B0%B8_%EA%B1%B0%EC%A7%93_%ED%8C%90%EB%8B%A8%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([2,4,6,8,10,12,14])
y = np.array([0,0,0,1,1,1,1])

model = Sequential()
model.add(Dense(1, input_dim=1, activation='sigmoid'))

#교차 엔트로피 함수를 이용하기 위해 binary_crossentropy 사용
model.compile(optimizer='sgd', loss='binary_crossentropy')
model.fit(x, y, epochs=5000, verbose=0) #verbose=0은 진행상황을 출력하지 않는다는 코드

plt.scatter(x,y)
plt.plot(x, model.predict(x), 'r')
plt.show()

#임의의 값 대입 후 예측
hour = 7
input_data = tf.constant([hour])
prediction = model.predict(input_data)[0][0]
print("%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다." %(hour, prediction * 100))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 7시간을 공부할 경우, 합격 예상 확률은 59.7%입니다.
